# %% [markdown]
# # Import the Necessary Libraries & Modules

# %%
from data.echogram import DataReaderZarr, get_data_readers
import numpy as np
from tqdm import tqdm
import dask
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage.morphology import binary_closing
from scipy import stats as st
from pandas.plotting import scatter_matrix
import xarray as xr
import seaborn as sns
from save_Sv_patch_data_docker.ipynb import examp_illustr

dask.config.set(**{'array.slicing.split_large_chunks': False})

#  Path to surveys
survey_path = '/data/'

#  Get list of relevant surveys
surveys = ['2019/S2019847/ACOUSTIC/GRIDDED/S2019847_sv.zarr']
readers = [DataReaderZarr(survey_path + zarr_file) for zarr_file in surveys]

# Or alternatively ...
# readers = get_data_readers()

patch_size = (256, 256)  # x, y

# %%
# Example Illustration for a patch - Echogram, annotations, Background Sv Distribution
def examp_illustr(survey, x, y, fig_start=-75, fig_finish=5, s_bin=5, db_w_limit=True, patch_size=[256, 256]):
    
    c = survey.get_label_slice(idx_ping= x - patch_size[0] // 2, n_pings=patch_size[0],
                               idx_range=int(y - patch_size[1] // 2), n_range=patch_size[1],
                               return_numpy=True)
    if db_w_limit:
        a = xr_db_with_limits(survey.get_data_slice(idx_ping= x - patch_size[0] // 2, n_pings=patch_size[0],
                                                    idx_range=int(y - patch_size[1] // 2), n_range=patch_size[1],
                                                    return_numpy=False, frequencies=[38000]))
        echo = a[0,:,:].values
        bg = a[0].values[np.logical_or(c==-1, c==0)] # Background
        
    else:
        a = survey.get_data_slice(idx_ping= x - patch_size[0] // 2, n_pings=patch_size[0],
                                  idx_range=int(y - patch_size[1] // 2), n_range=patch_size[1],
                                  return_numpy=False, frequencies=[38000])
        echo = db(a[0,:,:].values)
        bg = db(a[0].values[np.logical_or(c==-1, c==0)]) # Background             
        
        
        
    print('mean background Sv =', bg.mean(), ' median background Sv =', np.median(bg))
    print('mean Sandeel Sv =', a[0].values[c==27].mean(), ' median Sandeel Sv =', np.median(a[0].values[c==27]))
    # Echogram Plot
    plt.figure(figsize = (12,12))
    plt.suptitle('Patch Visualization at x='+str(x)+' and y='+str(y))
    
    plt.subplot(2,2,1)
    plt.title('Echogram')
    plt.imshow(echo.T)
    plt.colorbar()
    
    # Annotation Plot
    plt.subplot(2,2,3)
    plt.title('Annotations')
    plt.imshow(c.T)
    plt.colorbar()
        
    # Background Histogram Plot
    plt.subplot(2,2,2)
    plt.title('Background Sv Histogram')
    plt.hist(bg.flatten(), bins = np.arange(fig_start, fig_finish, s_bin), log = False)
    plt.xlabel('sv')
    plt.ylabel('Counts')
    plt.axvline(x=bg.mean(), color = 'black', label = 'mean')
    plt.axvline(x=np.median(bg), color = 'green', label = 'median')
    plt.axvline(x=np.nanpercentile(bg, 25), color = 'lightgray', label = '25 Percentile')
    plt.axvline(x=np.nanpercentile(bg, 75), color = 'dimgray', label = '75 Percentile')
    plt.legend()
        
    # Sandeel Histogram Plot
    plt.subplot(2,2,4)
    plt.title('Sandeel Sv Histogram')
    plt.hist(echo[c==27].flatten(),
             bins = np.arange(fig_start, fig_finish, s_bin), log = False)        
    plt.xlabel('Sv')
    plt.ylabel('Counts')
    plt.axvline(x=(echo[c==27].flatten()).mean(), color = 'red', label = 'Sandeel mean Sv')
    plt.axvline(x=np.median((echo[c==27].flatten())), color = 'orange', label = 'Sandeel median Sv')
    plt.axvline(x=np.nanpercentile(echo[c==27].flatten(), 25), color = 'lightgray', label = '25 Percentile')
    plt.axvline(x=np.nanpercentile(echo[c==27].flatten(), 75), color = 'dimgray', label = '75 Percentile')
    plt.legend()
    plt.show()

# %% [markdown]
# # Background Class

# %%
def xr_db_with_limits(xarr, limit_low=-75, limit_high=0): # Function to be applied to xarray dataarray
    data = db(xarr)
    result = data.where((data<limit_high) | (data.isnull()), limit_high)
    result = result.where((result>limit_low) | (result.isnull()), limit_low)
    return result

def db(data, eps=1e-10):
    return 10 * np.log10(data + eps)
# Out:
# 128

# %%
# Modified Background Sampler for y axis - Patches are selected within the water column only, no exceed
# Near field (first 20 rows) are also excluded. the interval = [20, (seabed - 128)]
class BackgroundZarr():
    def __init__(self, zarr_files, window_size=(256, 256)):
        """
        Sample from zarr-files
        :param zarr_files: (list)
        :param window_size: (tuple)
        """
        self.zarr_files = zarr_files
        self.window_size = window_size

    def get_sample(self):
        # Select random zarr file in list
        zarr_rand = np.random.choice(self.zarr_files)

        # select random ping in zarr file
        x = np.random.randint(self.window_size[1] // 2, zarr_rand.shape[0] - self.window_size[1] // 2)

        # Get y-loc above seabed
        seabed = int(zarr_rand.get_seabed(x))


        if seabed - (self.window_size[0]+20) <= 0:
            return self.get_sample()
        y = np.random.randint(self.window_size[0]//2 + 20, seabed-self.window_size[0]//2)


        # Check if any fish_labels in the crop
        labels = zarr_rand.get_label_slice(idx_ping=x-self.window_size[1]//2,
                                           n_pings=self.window_size[1],
                                           idx_range=max(0, y-self.window_size[0]//2),
                                           n_range=self.window_size[0],
                                           drop_na=False,
                                           return_numpy=False)

        # Check if any fish-labels in crop
        if (labels > 0).any() or (labels == -1).all(): # Possible bottleneck?
            return self.get_sample()

        return [x, y], zarr_rand

# %% [markdown]
# # 14351 tane background class patch var benim datada

# %%
survey = [readers[0]]

crdinates = np.zeros((15000,2)) 

for i in range(len(crdinates)):
    crdinates[i, :] = BackgroundZarr(survey).get_sample()[0]
    print(f"{i}th sample, Progress = %{100*i/len(crdinates)}")
# Out:
# 0th sample, Progress = %0.0
# 1th sample, Progress = %0.006666666666666667
# 2th sample, Progress = %0.013333333333333334
# 3th sample, Progress = %0.02
# 4th sample, Progress = %0.02666666666666667
# 5th sample, Progress = %0.03333333333333333
# 6th sample, Progress = %0.04
# 7th sample, Progress = %0.04666666666666667
# 8th sample, Progress = %0.05333333333333334
# 9th sample, Progress = %0.06
# 10th sample, Progress = %0.06666666666666667
# 11th sample, Progress = %0.07333333333333333
# 12th sample, Progress = %0.08
# 13th sample, Progress = %0.08666666666666667
# 14th sample, Progress = %0.09333333333333334
# 15th sample, Progress = %0.1
# 16th sample, Progress = %0.10666666666666667
# 17th sample, Progress = %0.11333333333333333
# 18th sample, Progress = %0.12
# 19th sample, Progress = %0.12666666666666668
# 20th sample, Progress = %0.13333333333333333
# 21th sample, Progress = %0.14
# 22th sample, Progress = %0.14666666666666667
# 23th sample, Progress = %0.15333333333333332
# 24th sample, Progress = %0.16
# 25th sample, Progress = %0.16666666666666666
# 26th sample, Progress = %0.17333333333333334
# 27th sample, Progress = %0.18
# 28th sample, Progress = %0.18666666666666668
# 29th sample, Progress = %0.19333333333333333
# 30th sample, Progress = %0.2
# 31th sample, Progress = %0.20666666666666667
# 32th sample, Progress = %0.21333333333333335
# 33th sample, Progress = %0.22
# 34th sample, Progress = %0.22666666666666666
# 35th sample, Progress = %0.23333333333333334
# 36th sample, Progress = %0.24
# 37th sample, Progress = %0.24666666666666667
# 38th sample, Progress = %0.25333333333333335
# 39th sample, Progress = %0.26
# 40th sample, Progress = %0.26666666666666666
# 41th sample, Progress = %0.2733333333333333
# 42th sample, Progress = %0.28
# 43th sample, Progress = %0.2866666666666667
# 44th sample, Progress = %0.29333333333333333
# 45th sample, Progress = %0.3
# 46th sample, Progress = %0.30666666666666664
# 47th sample, Progress = %0.31333333333333335
# 48th sample, Progress = %0.32
# 49th sample, Progress = %0.32666666666666666
# 50th sample, Progress = %0.3333333333333333
# 51th sample, Progress = %0.34
# 52th sample, Progress = %0.3466666666666667
# 53th sample, Progress = %0.35333333333333333
# 54th sample, Progress = %0.36
# 55th sample, Progress = %0.36666666666666664
# 56th sample, Progress = %0.37333333333333335
# 57th sample, Progress = %0.38
# 58th sample, Progress = %0.38666666666666666
# 59th sample, Progress = %0.3933333333333333
# 60th sample, Progress = %0.4
# 61th sample, Progress = %0.4066666666666667
# 62th sample, Progress = %0.41333333333333333
# 63th sample, Progress = %0.42
# 64th sample, Progress = %0.4266666666666667
# 65th sample, Progress = %0.43333333333333335
# 66th sample, Progress = %0.44
# 67th sample, Progress = %0.44666666666666666
# 68th sample, Progress = %0.4533333333333333
# 69th sample, Progress = %0.46
# 70th sample, Progress = %0.4666666666666667
# 71th sample, Progress = %0.47333333333333333
# 72th sample, Progress = %0.48
# 73th sample, Progress = %0.4866666666666667
# 74th sample, Progress = %0.49333333333333335
# 75th sample, Progress = %0.5
# 76th sample, Progress = %0.5066666666666667
# 77th sample, Progress = %0.5133333333333333
# 78th sample, Progress = %0.52
# 79th sample, Progress = %0.5266666666666666
# 80th sample, Progress = %0.5333333333333333
# 81th sample, Progress = %0.54
# 82th sample, Progress = %0.5466666666666666
# 83th sample, Progress = %0.5533333333333333
# 84th sample, Progress = %0.56
# 85th sample, Progress = %0.5666666666666667
# 86th sample, Progress = %0.5733333333333334
# 87th sample, Progress = %0.58
# 88th sample, Progress = %0.5866666666666667
# 89th sample, Progress = %0.5933333333333334
# 90th sample, Progress = %0.6
# 91th sample, Progress = %0.6066666666666667
# 92th sample, Progress = %0.6133333333333333
# 93th sample, Progress = %0.62
# 94th sample, Progress = %0.6266666666666667
# 95th sample, Progress = %0.6333333333333333
# 96th sample, Progress = %0.64
# 97th sample, Progress = %0.6466666666666666
# 98th sample, Progress = %0.6533333333333333
# 99th sample, Progress = %0.66
# 100th sample, Progress = %0.6666666666666666
# 101th sample, Progress = %0.6733333333333333
# 102th sample, Progress = %0.68
# 103th sample, Progress = %0.6866666666666666
# 104th sample, Progress = %0.6933333333333334
# 105th sample, Progress = %0.7
# 106th sample, Progress = %0.7066666666666667
# 107th sample, Progress = %0.7133333333333334
# 108th sample, Progress = %0.72
# 109th sample, Progress = %0.7266666666666667
# 110th sample, Progress = %0.7333333333333333
# 111th sample, Progress = %0.74
# 112th sample, Progress = %0.7466666666666667
# 113th sample, Progress = %0.7533333333333333
# 114th sample, Progress = %0.76
# 115th sample, Progress = %0.7666666666666667
# 116th sample, Progress = %0.7733333333333333
# 117th sample, Progress = %0.78
# 118th sample, Progress = %0.7866666666666666
# 119th sample, Progress = %0.7933333333333333
# 120th sample, Progress = %0.8
# 121th sample, Progress = %0.8066666666666666
# 122th sample, Progress = %0.8133333333333334
# 123th sample, Progress = %0.82
# 124th sample, Progress = %0.8266666666666667
# 125th sample, Progress = %0.8333333333333334
# 126th sample, Progress = %0.84
# 127th sample, Progress = %0.8466666666666667
# 128th sample, Progress = %0.8533333333333334
# 129th sample, Progress = %0.86
# 130th sample, Progress = %0.8666666666666667
# 131th sample, Progress = %0.8733333333333333
# 132th sample, Progress = %0.88
# 133th sample, Progress = %0.8866666666666667
# 134th sample, Progress = %0.8933333333333333
# 135th sample, Progress = %0.9
# 136th sample, Progress = %0.9066666666666666
# 137th sample, Progress = %0.9133333333333333
# 138th sample, Progress = %0.92
# 139th sample, Progress = %0.9266666666666666
# 140th sample, Progress = %0.9333333333333333
# 141th sample, Progress = %0.94
# 142th sample, Progress = %0.9466666666666667
# 143th sample, Progress = %0.9533333333333334
# 144th sample, Progress = %0.96
# 145th sample, Progress = %0.9666666666666667
# 146th sample, Progress = %0.9733333333333334
# 147th sample, Progress = %0.98
# 148th sample, Progress = %0.9866666666666667
# 149th sample, Progress = %0.9933333333333333
# 150th sample, Progress = %1.0
# 151th sample, Progress = %1.0066666666666666
# 152th sample, Progress = %1.0133333333333334
# 153th sample, Progress = %1.02
# 154th sample, Progress = %1.0266666666666666
# 155th sample, Progress = %1.0333333333333334
# 156th sample, Progress = %1.04
# 157th sample, Progress = %1.0466666666666666
# 158th sample, Progress = %1.0533333333333332
# 159th sample, Progress = %1.06
# 160th sample, Progress = %1.0666666666666667
# 161th sample, Progress = %1.0733333333333333
# 162th sample, Progress = %1.08
# 163th sample, Progress = %1.0866666666666667
# 164th sample, Progress = %1.0933333333333333
# 165th sample, Progress = %1.1
# 166th sample, Progress = %1.1066666666666667
# 167th sample, Progress = %1.1133333333333333
# 168th sample, Progress = %1.12
# 169th sample, Progress = %1.1266666666666667
# 170th sample, Progress = %1.1333333333333333
# 171th sample, Progress = %1.14
# 172th sample, Progress = %1.1466666666666667
# 173th sample, Progress = %1.1533333333333333
# 174th sample, Progress = %1.16
# 175th sample, Progress = %1.1666666666666667
# 176th sample, Progress = %1.1733333333333333
# 177th sample, Progress = %1.18
# 178th sample, Progress = %1.1866666666666668
# 179th sample, Progress = %1.1933333333333334
# 180th sample, Progress = %1.2
# 181th sample, Progress = %1.2066666666666668
# 182th sample, Progress = %1.2133333333333334
# 183th sample, Progress = %1.22
# 184th sample, Progress = %1.2266666666666666
# 185th sample, Progress = %1.2333333333333334
# 186th sample, Progress = %1.24
# 187th sample, Progress = %1.2466666666666666
# 188th sample, Progress = %1.2533333333333334
# 189th sample, Progress = %1.26
# 190th sample, Progress = %1.2666666666666666
# 191th sample, Progress = %1.2733333333333334
# 192th sample, Progress = %1.28
# 193th sample, Progress = %1.2866666666666666
# 194th sample, Progress = %1.2933333333333332
# 195th sample, Progress = %1.3
# 196th sample, Progress = %1.3066666666666666
# 197th sample, Progress = %1.3133333333333332
# 198th sample, Progress = %1.32
# 199th sample, Progress = %1.3266666666666667
# 200th sample, Progress = %1.3333333333333333
# 201th sample, Progress = %1.34
# 202th sample, Progress = %1.3466666666666667
# 203th sample, Progress = %1.3533333333333333
# 204th sample, Progress = %1.36
# 205th sample, Progress = %1.3666666666666667
# 206th sample, Progress = %1.3733333333333333
# 207th sample, Progress = %1.38
# 208th sample, Progress = %1.3866666666666667
# 209th sample, Progress = %1.3933333333333333
# 210th sample, Progress = %1.4
# 211th sample, Progress = %1.4066666666666667
# 212th sample, Progress = %1.4133333333333333
# 213th sample, Progress = %1.42
# 214th sample, Progress = %1.4266666666666667
# 215th sample, Progress = %1.4333333333333333
# 216th sample, Progress = %1.44
# 217th sample, Progress = %1.4466666666666668
# 218th sample, Progress = %1.4533333333333334
# 219th sample, Progress = %1.46
# 220th sample, Progress = %1.4666666666666666
# 221th sample, Progress = %1.4733333333333334
# 222th sample, Progress = %1.48
# 223th sample, Progress = %1.4866666666666666
# 224th sample, Progress = %1.4933333333333334
# 225th sample, Progress = %1.5
# 226th sample, Progress = %1.5066666666666666
# 227th sample, Progress = %1.5133333333333334
# 228th sample, Progress = %1.52
# 229th sample, Progress = %1.5266666666666666
# 230th sample, Progress = %1.5333333333333334
# 231th sample, Progress = %1.54
# 232th sample, Progress = %1.5466666666666666
# 233th sample, Progress = %1.5533333333333332
# 234th sample, Progress = %1.56
# 235th sample, Progress = %1.5666666666666667
# 236th sample, Progress = %1.5733333333333333
# 237th sample, Progress = %1.58
# 238th sample, Progress = %1.5866666666666667
# 239th sample, Progress = %1.5933333333333333
# 240th sample, Progress = %1.6
# 241th sample, Progress = %1.6066666666666667
# 242th sample, Progress = %1.6133333333333333
# 243th sample, Progress = %1.62
# 244th sample, Progress = %1.6266666666666667
# 245th sample, Progress = %1.6333333333333333
# 246th sample, Progress = %1.64
# 247th sample, Progress = %1.6466666666666667
# 248th sample, Progress = %1.6533333333333333
# 249th sample, Progress = %1.66
# 250th sample, Progress = %1.6666666666666667
# 251th sample, Progress = %1.6733333333333333
# 252th sample, Progress = %1.68
# 253th sample, Progress = %1.6866666666666668
# 254th sample, Progress = %1.6933333333333334
# 255th sample, Progress = %1.7
# 256th sample, Progress = %1.7066666666666668
# 257th sample, Progress = %1.7133333333333334
# 258th sample, Progress = %1.72
# 259th sample, Progress = %1.7266666666666666
# 260th sample, Progress = %1.7333333333333334
# 261th sample, Progress = %1.74
# 262th sample, Progress = %1.7466666666666666
# 263th sample, Progress = %1.7533333333333334
# 264th sample, Progress = %1.76
# 265th sample, Progress = %1.7666666666666666
# 266th sample, Progress = %1.7733333333333334
# 267th sample, Progress = %1.78
# 268th sample, Progress = %1.7866666666666666
# 269th sample, Progress = %1.7933333333333332
# 270th sample, Progress = %1.8
# 271th sample, Progress = %1.8066666666666666
# 272th sample, Progress = %1.8133333333333332
# 273th sample, Progress = %1.82
# 274th sample, Progress = %1.8266666666666667
# 275th sample, Progress = %1.8333333333333333
# 276th sample, Progress = %1.84
# 277th sample, Progress = %1.8466666666666667
# 278th sample, Progress = %1.8533333333333333
# 279th sample, Progress = %1.86
# 280th sample, Progress = %1.8666666666666667
# 281th sample, Progress = %1.8733333333333333
# 282th sample, Progress = %1.88
# 283th sample, Progress = %1.8866666666666667
# 284th sample, Progress = %1.8933333333333333
# 285th sample, Progress = %1.9
# 286th sample, Progress = %1.9066666666666667
# 287th sample, Progress = %1.9133333333333333
# 288th sample, Progress = %1.92
# 289th sample, Progress = %1.9266666666666667
# 290th sample, Progress = %1.9333333333333333
# 291th sample, Progress = %1.94
# 292th sample, Progress = %1.9466666666666668
# 293th sample, Progress = %1.9533333333333334
# 294th sample, Progress = %1.96
# 295th sample, Progress = %1.9666666666666666
# 296th sample, Progress = %1.9733333333333334
# 297th sample, Progress = %1.98
# 298th sample, Progress = %1.9866666666666666
# 299th sample, Progress = %1.9933333333333334
# 300th sample, Progress = %2.0
# 301th sample, Progress = %2.006666666666667
# 302th sample, Progress = %2.013333333333333
# 303th sample, Progress = %2.02

# %%
for i in range(3):
    examp_illustr(survey[0], x=int(crdinates[i,0]), y=int(crdinates[i,1]))
# Out:
# mean background Sv = -68.86389  median background Sv = -69.54358
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# mean Sandeel Sv = nan  median Sandeel Sv = nan
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:59: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# mean background Sv = -66.779396  median background Sv = -66.88663
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# mean Sandeel Sv = nan  median Sandeel Sv = nan
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:59: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# mean background Sv = -67.037186  median background Sv = -66.79813
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# mean Sandeel Sv = nan  median Sandeel Sv = nan
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:59: RuntimeWarning: Mean of empty slice.
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
